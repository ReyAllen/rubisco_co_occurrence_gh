# %%
import os
path='/Users/tonglen/downloads/rub-co-occurrence-master_2/'
os.chdir(path)

os.getcwd()
# Out:
# '/Users/tonglen/Downloads/rub-co-occurrence-master_2'

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from os import path
from matplotlib import pyplot as plt
from urllib.parse import urlencode
from urllib.request import urlretrieve

# %%
# Helper function for making an UniprotKB query string for their REST API.
# Must provide ONE of pfam, interpro or EC
def format_query_url(pfam=None, interpro=None, EC=None):
    base_url = 'https://www.uniprot.org/uniprot/?'
    columns = (  # columns we want to request
        'id,entry name,genes,genes(ORF),organism,organism-id,length,mass,sequence,ec,fragment,' +
        'comment(PATHWAY),annotation score,reviewed,' + 
        'feature(INTRAMEMBRANE),feature(TRANSMEMBRANE),database(INTERPRO),database(PFAM),database(PROSITE),' +
        'lineage(SUPERKINGDOM),lineage(PHYLUM),lineage(CLASS),lineage(ORDER),comment(COFACTOR),protein names'
    )
    
    
    # build the query in a manner that depends on the parameters supplied
    query_str = ''
    if pfam is not None:
        query_str = 'database:(type:pfam %s)' % pfam
    elif interpro is not None:
        query_str = 'database:(type:interpro %s)' % interpro
    elif EC is not None:
        query_str = 'ec:%s' % EC
    else:
        assert False, 'you suck, you didnt set any params for search.'
    
    # urlencode the query string and format the full URL.
    url_query = {'query': query_str,
                 'sort': 'score',
                 'columns': columns,
                 'format': 'tab'}
    encoded_query = urlencode(url_query)
    
    full_url = ''.join([base_url, encoded_query])
    return full_url

# %%
# Opening the queries as a dataframe - one query per row determined by a PFAM, INTERPRO ID or EC class.
queries_filename = 'uniprotKB_queries.csv'
queries_df = pd.read_csv(queries_filename, sep = '\t')
# Hack - pandas sets empty values to NaN which do not evaluate to False.
# Replace NaN with None which does evaluate to False.
queries_df[queries_df.isnull()] = None
queries_df
# Out:
#           gene_name     pfam   interpro         EC  \
# 0     rubisco_small  pf00101       None       None
# 1            FormIV     None       None       None
# 2          FormIIIc     None       None       None
# 3          FormIIIb     None       None       None
# 4            FormIe     None       None       None
# 5            FormIC     None       None       None
# 6           FormIBc     None       None       None
# 7           FormIAq     None       None       None
# 8           FormIAc     None       None       None
# 9        FormIA_all     None       None       None
# 10        FormI_all     None       None       None
# 11      FormIII_all     None       None       None
# 12           FormII     None       None       None
# 13       FormII_III     None       None       None
# 14       FormII_all     None       None       None
# 15           sbpase     None       None   3.1.3.37
# 16             glpX     None       None   3.1.3.11
# 17    rubisco_large  pf00016       None       None
# 18              prk     None       None   2.7.1.19
# 19             dabA  pf10070       None       None
# 20             sbtA  pf05982       None       None
# 21             bicA  pf00916       None       None
# 22           cupABS  pf10216       None       None
# 23      bmc_hexamer  pf00936       None       None
# 24     bmc_pentamer  pf03319       None       None
# 25           csosCA  pf08936       None       None
# 26   prokaryotic_CA  pf00484       None       None
# 27            csos2  pf12288       None       None
# 28  2pg_phosphatase     None       None   3.1.3.18
# 29       2pg_phosph     None  IPR037512       None
# 30              hps     None       None   4.1.2.43
# 31              phi     None       None   5.3.1.27
# 32             bchG     None  IPR006372       None
# 33            chl_A     None       None   2.5.1.62
# 34             bchP     None       None   1.3.1.83
# 35             bchG     None       None  2.5.1.133
# 36           all_CA     None       None    4.2.1.1
# 37             psbU  PF06514       None       None
# 38             ccmM     None  IPR017156       None
# 39             ccmO     None  IPR020808       None
#
#                                                 notes  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  prk + rubisco + sbpase = high likelihood of ca...
# 16  also listed as sbase; see https://www.genome.j...
# 17                                           4.1.1.39
# 18  Phosophoribulose kinase. Prk + rubisco + sbpas...
# 19                                  Ci_uptake_markers
# 20                                  Ci_uptake_markers
# 21                                  Ci_uptake_markers
# 22                                  Ci_uptake_markers
# 23                         both alpha and beta csomes
# 24                         both alpha and beta csomes
# 25               alpha csomes = bmcs + csosCA + csos2
# 26                        generic prokaryotic beta CA
# 27               alpha csomes = bmcs + csosCA + csos2
# 28  2-phosphoglycolate phosphatase. Original photo...
# 29  check to see if interpro marker gives better t...
# 30                    hexulose monophosphate synthase
# 31                                 hexulose isomerase
# 32                original bacteriochlorophyll marker
# 33  chlA synthase. only found in plants and cyanos...
# 34                                          1.3.1.111
# 35             used to make bchlA and bchlB and bchlC
# 36                        all the carbonic anhydrases
# 37  extrinsic protein of OEC (one of core OEC prot...
# 38                        CO2_concentrating_prot_CcmM
# 39                                  Bact_microcomp_CS
#
#                                            Unnamed: 5  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28   Searching by EC because lots of phosphatases ...
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33
# 34   used to make bchlA. Both enzymes can act on bchl
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39  This entry represents a conserved region at th...
#
#                                            Unnamed: 6
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34   only the second one is specific to bchl (1.3....
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None

# %%
# For each row in the dataframe
for row_id, row in queries_df.iterrows():
    # Determine if there is enough information to make a query
    # - need one of the three fields below.
    if not row.pfam and not row.interpro and not row.EC:
        print('No query, skipping')
        continue
            
    # Make the query
    q = format_query_url(pfam=row.pfam, interpro=row.interpro, EC=row.EC)
    print(row.gene_name)
    print('%s' % q)
    
    # Format the output filename
    out_fname = 'uniprotKB_downloads/%s.csv' % row.gene_name
    # read the file to this folder.
    
    # skip if output exists.
    if path.exists(out_fname):
        print('file exists, skipping')
        continue
    
    try:
        # Try to read the file from the Uniprot API into a local file.
        urlretrieve(q, out_fname)
    except Error as e:
        print(e)
        continue
# Out:
# rubisco_small
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf00101%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# No query, skipping
# sbpase
# https://www.uniprot.org/uniprot/?query=ec%3A3.1.3.37&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# glpX
# https://www.uniprot.org/uniprot/?query=ec%3A3.1.3.11&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# rubisco_large
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf00016%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# prk
# https://www.uniprot.org/uniprot/?query=ec%3A2.7.1.19&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# dabA
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf10070%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# sbtA
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf05982%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# bicA
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf00916%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# cupABS
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf10216%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# bmc_hexamer
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf00936%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# bmc_pentamer
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf03319%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# csosCA
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf08936%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# prokaryotic_CA
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf00484%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# csos2
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+pf12288%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# 2pg_phosphatase
# https://www.uniprot.org/uniprot/?query=ec%3A3.1.3.18&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# 2pg_phosph
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Ainterpro+IPR037512%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# hps
# https://www.uniprot.org/uniprot/?query=ec%3A4.1.2.43&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# phi
# https://www.uniprot.org/uniprot/?query=ec%3A5.3.1.27&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# bchG
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Ainterpro+IPR006372%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# chl_A
# https://www.uniprot.org/uniprot/?query=ec%3A2.5.1.62&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# bchP
# https://www.uniprot.org/uniprot/?query=ec%3A1.3.1.83&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# bchG
# https://www.uniprot.org/uniprot/?query=ec%3A2.5.1.133&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# all_CA
# https://www.uniprot.org/uniprot/?query=ec%3A4.2.1.1&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# psbU
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Apfam+PF06514%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# ccmM
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Ainterpro+IPR017156%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
# ccmO
# https://www.uniprot.org/uniprot/?query=database%3A%28type%3Ainterpro+IPR020808%29&sort=score&columns=id%2Centry+name%2Cgenes%2Cgenes%28ORF%29%2Corganism%2Corganism-id%2Clength%2Cmass%2Csequence%2Cec%2Cfragment%2Ccomment%28PATHWAY%29%2Cannotation+score%2Creviewed%2Cfeature%28INTRAMEMBRANE%29%2Cfeature%28TRANSMEMBRANE%29%2Cdatabase%28INTERPRO%29%2Cdatabase%28PFAM%29%2Cdatabase%28PROSITE%29%2Clineage%28SUPERKINGDOM%29%2Clineage%28PHYLUM%29%2Clineage%28CLASS%29%2Clineage%28ORDER%29%2Ccomment%28COFACTOR%29%2Cprotein+names&format=tab
# file exists, skipping
